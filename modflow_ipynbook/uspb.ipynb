# %%
import os
import sys
import numpy as np
import scipy.ndimage
import matplotlib as mpl
import matplotlib.pyplot as plt
import flopy

# %%
cf = np.loadtxt("/home/nandahgy/modflow_ipynbook/input.dat")
print(cf.shape)
# Out:
# (110, 80)

# %%
cf2 = scipy.ndimage.zoom(cf, 4, order=0)
print(cf2.shape)
# Out:
# (440, 320)

# %%
c = plt.imshow(cf2, cmap='jet')
plt.colorbar(c);
